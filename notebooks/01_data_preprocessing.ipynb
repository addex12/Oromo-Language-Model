# %%
# Use a pipeline as a high-level helper
from transformers import pipeline

pipe = pipeline("translation", model="Helsinki-NLP/opus-mt-en-om")
# Load model directly
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

tokenizer = AutoTokenizer.from_pretrained("Helsinki-NLP/opus-mt-en-om")
model = AutoModelForSeq2SeqLM.from_pretrained("Helsinki-NLP/opus-mt-en-om")
# Out:
# 2025-02-25 00:58:05.256400: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/anaconda3/envs/Afaan_Oromo_Translation/lib/python3.9/site-packages/transformers/utils/import_utils.py:1863, in _LazyModule._get_module(self, module_name)
#    1862 try:
# -> 1863     return importlib.import_module("." + module_name, self.__name__)
#    1864 except Exception as e:
#
# File ~/anaconda3/envs/Afaan_Oromo_Translation/lib/python3.9/importlib/__init__.py:127, in import_module(name, package)
#     126         level += 1
# ...

# %%
pip install transformers==4.25.0 scipy==1.7.3 scikit-learn==0.24.2 tensorflow==2.8.0
# Out:
# ...
#   Using cached libclang-18.1.1-py2.py3-none-manylinux2010_x86_64.whl.metadata (5.2 kB)
# ...
#   Using cached tensorflow_io_gcs_filesystem-0.37.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (14 kB)
# ...
# WARNING: The candidate selected for download or install is a yanked version: 'transformers' candidate (version 4.25.0 at https://files.pythonhosted.org/packages/2b/a6/b32ba581c064276dc254a4c2bdf5301a942fa28a4a9b41209d8909da37d2/transformers-4.25.0-py3-none-any.whl (from https://pypi.org/simple/transformers/) (requires-python:>=3.7.0))
# Reason for being yanked: Version was not properly set
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 988.9 kB/s eta 0:00:000:00:01m eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.8/39.8 MB 1.7 MB/s eta 0:00:00m eta 0:00:010:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.8/23.8 MB 1.5 MB/s eta 0:00:00m eta 0:00:010:01:01
# ...
#    ━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.3/497.6 MB 2.1 MB/s eta 0:03:40:39
